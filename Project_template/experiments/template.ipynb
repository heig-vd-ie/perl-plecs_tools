# %% [markdown]
# # Jupyter notebook Template of PERL
#
# The purpose of this template is to serve as a starting point when creating a project.

# %%
import src.template_test as template_test

# %% [markdown]
# ---
# ##  Print Hello, World!

# %%
template_test.print_hello(3)
# Out:
# Hello, World!
# Hello, World!
# Hello, World!
